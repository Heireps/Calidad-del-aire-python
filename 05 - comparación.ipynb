# %% [markdown]
# # Comparación de modelos

# %%
from sklearn.metrics import accuracy_score

acc1 = accuracy_score(y_prueba, modelo1.predict(X_prueba))
acc2 = accuracy_score(y_prueba, modelo2.predict(X_prueba))
print('Modelo 1:', acc1, 'Modelo 2:', acc2)
